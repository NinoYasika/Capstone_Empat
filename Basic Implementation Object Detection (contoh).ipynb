# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -qU ultralytics supervision
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.2/207.2 kB 20.1 MB/s eta 0:00:00

# %%
import cv2
import supervision as sv
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Purwadhika/Solusi Exercise dan Catatan Hands On/Sesi 4/14. Review and Mentoring/yolov12n_general.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
image = cv2.imread('/content/drive/MyDrive/Purwadhika/Solusi Exercise dan Catatan Hands On/Sesi 4/14. Review and Mentoring/test_img.jpg')
results = model(image, verbose=False)[0]
detections = sv.Detections.from_ultralytics(results).with_nms()
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()
annotated_image = image.copy()
annotated_image = box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)
sv.plot_image(annotated_image)

# %%
detections
# Out:
# Detections(xyxy=array([[     744.41,       227.4,      919.81,      403.48],
#        [     679.72,      182.53,      784.65,      287.41],
#        [     590.96,      390.07,      716.47,      522.75],
#        [     178.22,      361.34,      287.16,       451.1],
#        [     470.54,      145.28,       489.8,      159.33]], dtype=float32), mask=None, confidence=array([    0.92009,     0.88966,     0.84528,     0.83625,     0.31787], dtype=float32), class_id=array([5, 5, 2, 2, 2]), tracker_id=None, data={'class_name': array(['bus', 'bus', 'car', 'car', 'car'], dtype='<U3')}, metadata={})
